# %%
from pgmpy.base import DAG

# Default (Erdős–Rényi)
G1 = DAG.get_random(n_nodes=8, edge_prob=0.3, method="erdos")

# Connected variant
G2 = DAG.get_random(n_nodes=8, edge_prob=0.3, method="spanning_tree")

# Preferential attachment
G3 = DAG.get_random(n_nodes=10, method="preferential", m=3)

# Layered (hierarchical)
G4 = DAG.get_random(n_nodes=12, method="layered", n_layers=3, layer_conn_prob=0.4)

# %%
for i in range(1,5):
    print(eval(f"G{i}"))
# Out:
# DAG with 8 nodes and 7 edges
# DAG with 8 nodes and 17 edges
# DAG with 10 nodes and 24 edges
# DAG with 12 nodes and 10 edges

# %%
from pgmpy.models import DiscreteBayesianNetwork as bn

# Default (Erdős–Rényi)
b1 = bn.get_random(n_nodes=8, edge_prob=0.3, method="erdos")

# Connected variant
b2 = bn.get_random(n_nodes=8, edge_prob=0.7, method="spanning_tree")

# Preferential attachment
b3 = bn.get_random(n_nodes=8, method="preferential", m=2)

# Layered (hierarchical)
b4 = bn.get_random(n_nodes=8, method="layered", n_layers=3, layer_conn_prob=0.7)

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Get an example model
from pgmpy.utils import get_example_model

# %%
for i in range(1,5):
    model =  eval(f"b{i}")    
    model_daft = model.to_daft()
    # To open the plot
    model_daft.render()
