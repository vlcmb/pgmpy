# %%
from pgmpy.base import DAG

# Default (Erdős–Rényi)
G1 = DAG.get_random(n_nodes=8, edge_prob=0.3, method="erdos")

# Connected variant
G2 = DAG.get_random(n_nodes=8, edge_prob=0.3, method="spanning_tree")

# Preferential attachment
G3 = DAG.get_random(n_nodes=10, method="preferential", m=3)

# Layered (hierarchical)
G4 = DAG.get_random(n_nodes=12, method="layered", n_layers=3, layer_conn_prob=0.4)

# %%
for i in range(1,5):
    print(eval(f"G{i}"))
# Out:
# DAG with 8 nodes and 8 edges
# DAG with 8 nodes and 12 edges
# DAG with 10 nodes and 24 edges
# DAG with 12 nodes and 17 edges

# %%
from pgmpy.models import DiscreteBayesianNetwork as bn

# Default (Erdős–Rényi)
b1 = bn.get_random(n_nodes=8, edge_prob=0.3, method="erdos")

# Connected variant
b2 = bn.get_random(n_nodes=8, edge_prob=0.3, method="spanning_tree")

# Preferential attachment
b3 = bn.get_random(n_nodes=10, method="preferential", m=3)

# Layered (hierarchical)
b4 = bn.get_random(n_nodes=12, method="layered", n_layers=3, layer_conn_prob=0.4)

# %%
! uv add pygraphviz
# Out:
# Resolved 165 packages in 0.78ms
#    Building pygraphviz==1.14
#    Building pygraphviz==1.14
#    Building pgmpy @ file:///home/valentin/Documents/Adada/Adada/pgmpy/pgm_try_node_p
#    Building pygraphviz==1.14
#    Building pgmpy @ file:///home/valentin/Documents/Adada/Adada/pgmpy/pgm_try_node_p
#    Building pygraphviz==1.14
#    Building pgmpy @ file:///home/valentin/Documents/Adada/Adada/pgmpy/pgm_try_node_p
#    Building pygraphviz==1.14
#   × Failed to build `pygraphviz==1.14`m==1.14
#   ├─▶ The build backend returned an error
#   ╰─▶ Call to `setuptools.build_meta.build_wheel` failed (exit status: 1)
#
#       [stdout]
#       running bdist_wheel
#       running build
#       running build_py
#       copying pygraphviz/scraper.py ->
#       build/lib.linux-x86_64-cpython-312/pygraphviz
#       copying pygraphviz/testing.py ->
#       build/lib.linux-x86_64-cpython-312/pygraphviz
#       copying pygraphviz/__init__.py ->
#       build/lib.linux-x86_64-cpython-312/pygraphviz
# ...

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Get an example model
from pgmpy.utils import get_example_model
# Out:
# INFO:matplotlib.font_manager:Failed to extract font properties from /usr/share/fonts/truetype/noto/NotoColorEmoji.ttf: Can not load face (unknown file format; error code 0x2)
# INFO:matplotlib.font_manager:generated new fontManager

# %%
pip install pygraphviz
# Out:
# ...
#   Using cached pygraphviz-1.14.tar.gz (106 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for pygraphviz (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [98 lines of output]
#       /tmp/pip-build-env-d2_e_9g1/overlay/lib/python3.12/site-packages/setuptools/config/_apply_pyprojecttoml.py:82: SetuptoolsDeprecationWarning: `project.license` as a TOML table is deprecated
#       !!
#
#               ********************************************************************************
#               Please use a simple string containing a SPDX expression for `project.license`. You can also use `project.license-files`. (Both options available on setuptools>=77.0.0).
#
#               By 2026-Feb-18, you need to update your project and remove deprecated calls
# ...

# %%
for i in range(1,5):
    model =  eval(f"b{i}")
    model_graphviz = model.to_graphviz()
    model_graphviz.draw()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Documents/Adada/Adada/pgmpy/pgm_try_node_perso/pgmpy/.venv/lib/python3.12/site-packages/networkx/drawing/nx_agraph.py:134, in to_agraph(N)
#     133 try:
# --> 134     import pygraphviz
#     135 except ImportError as err:
#
# ModuleNotFoundError: No module named 'pygraphviz'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[29], line 3
#       1 for i in range(1,5):
#       2     model =  eval(f"b{i}")
# ----> 3     model_graphviz = model.to_graphviz()
#       4     model_graphviz.draw()
#
# File ~/Documents/Adada/Adada/pgmpy/pgm_try_node_perso/pgmpy/pgmpy/base/DAG.py:1504, in DAG.to_graphviz(self, plot_edge_strength)
#    1498     if missing_strengths:
#    1499         raise ValueError(
# ...
